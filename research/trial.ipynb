# %% [markdown]
# ### Data Ingestion

# %%
# Data Ingestion
from langchain_core.documents import Document

# %%
doc = Document(
    page_content="Hello, My name is Pranjal Singh. I am from Tundla.",
    metadata = {
        "source":"example.txt",
        "pages":1,
        "author":"Pranjal Singh",
        "data_created":"2025-11-08"
    }
)
doc
# Out:
# Document(metadata={'source': 'example.txt', 'pages': 1, 'author': 'Pranjal Singh', 'data_created': '2025-11-08'}, page_content='Hello, My name is Pranjal Singh. I am from Tundla.')
